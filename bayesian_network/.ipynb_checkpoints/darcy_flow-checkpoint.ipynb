# %%
try:
     from dlroms import *
except:
     # !pip install git+https://github.com/NicolaRFranco/dlroms.git
     from dlroms import *
# Out:
# /home/frabet/.local/lib/python3.10/site-packages/dlroms/fespaces.py:48: UserWarning: Either dolfin or fenics are not available. Some functions might not be available or work as expected.
#   warnings.warn("Either dolfin or fenics are not available. Some functions might not be available or work as expected.")

# %%
from dlroms import *
# from dlroms.gp import GaussianRandomField
from geogp import GaussianRandomField
import numpy as np
from dolfin import *
from IPython.display import clear_output as clc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 from dlroms import *
#       2 # from dlroms.gp import GaussianRandomField
# ----> 3 from geogp import GaussianRandomField
#       4 import numpy as np
#       5 from dolfin import *
#
# File /mnt/c/Users/frabe/Desktop/PoliMi/Master/II/PACS/Projects/APSC_project/bayesian_network/geogp.py:2
#       1 from dlroms import fespaces
# ----> 2 import dolfin
#       3 import numpy as np
#       4 import scipy.sparse.linalg as spla
#
# ModuleNotFoundError: No module named 'dolfin'

# %% [markdown]
# ### Setup

# %%
# Domain definition

# domain = fe.circle((0.0, 0.0), 1) - fe.circle((0.0, 0.0), 0.4)
domain = fe.rectangle((0.0, 0.0), (1.0, 1.0)) - fe.rectangle((0.3, 0.3), (0.7, 0.7))
mesh = fe.mesh(domain, stepsize=0.03)
V = fe.space(mesh, 'CG', 1)
clc()

plt.figure(figsize=(3, 3))
fe.plot(mesh)

print('FE space dimension:', V.dim())
# Out:
# FE space dimension: 1277

# %%
# Input random field definition

l = 0.1 # length scale
ker = lambda r: np.exp(- r ** 2 / l)
KLE_dims = [10, 50, 500, 4255]
# K = GaussianRandomField(mesh, kernel=ker, upto=KLE_dims[1]) # Euclidean version
K_geo = GaussianRandomField(domain, mesh, kernel=ker, upto=KLE_dims[0]) # the dlrom version DOES NOT WORK (gmsh vs mshr?)
clc()

# %%
test_sample
# Out:
# array([nan, nan, nan, ..., nan, nan, nan])

# %%
# test_sample = K.sample(0)
test_sample = K_geo.sample(0)

plt.figure(figsize=(3, 3))
fe.plot(test_sample, V, cmap='jet')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/dlroms-env/lib/python3.11/site-packages/dlroms/fespaces.py:338, in plot(obj, space, vmin, vmax, colorbar, axis, shrink, levels, cmap)
#     337 if(space.element().value_dimension(0) == 1):
# --> 338     c = dolfin.common.plotting.plot(uv, vmin = vmin, vmax = vmax, levels = numpy.linspace(float(obj.min()), float(obj.max()), levels), cmap = cmap)
#     339 else:
#
# File ~/miniconda3/envs/dlroms-env/lib/python3.11/site-packages/dolfin/common/plotting.py:438, in plot(object, *args, **kwargs)
#     437 if backend == "matplotlib":
# --> 438     return _plot_matplotlib(object, mesh, kwargs)
#     439 elif backend == "x3dom":
#
# File ~/miniconda3/envs/dlroms-env/lib/python3.11/site-packages/dolfin/common/plotting.py:304, in _plot_matplotlib(obj, mesh, kwargs)
#     303 if isinstance(obj, cpp.function.Function):
# --> 304     return mplot_function(ax, obj, **kwargs)
#     305 elif isinstance(obj, cpp.function.Expression):
#
# File ~/miniconda3/envs/dlroms-env/lib/python3.11/site-packages/dolfin/common/plotting.py:152, in mplot_function(ax, f, **kwargs)
#     151     levels = kwargs.pop("levels", 40)
# --> 152     return ax.tricontourf(mesh2triang(mesh), C, levels, **kwargs)
#     153 elif mode == "color":
#
# File ~/miniconda3/envs/dlroms-env/lib/python3.11/site-packages/matplotlib/tri/_tricontour.py:272, in tricontourf(ax, *args, **kwargs)
#     271 kwargs['filled'] = True
# --> 272 return TriContourSet(ax, *args, **kwargs)
#
# File ~/miniconda3/envs/dlroms-env/lib/python3.11/site-packages/matplotlib/tri/_tricontour.py:29, in TriContourSet.__init__(self, ax, *args, **kwargs)
#      20 """
#      21 Draw triangular grid contour lines or filled regions,
#      22 depending on whether keyword arg *filled* is False
#    (...)
#      27 are described in the docstring of `~.Axes.tricontour`.
#      28 """
# ---> 29 super().__init__(ax, *args, **kwargs)
#
# File ~/miniconda3/envs/dlroms-env/lib/python3.11/site-packages/matplotlib/contour.py:847, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     844     self.negative_linestyles = \
#     845         mpl.rcParams['contour.negative_linestyle']
# --> 847 kwargs = self._process_args(*args, **kwargs)
#     848 self._process_levels()
#
# File ~/miniconda3/envs/dlroms-env/lib/python3.11/site-packages/matplotlib/tri/_tricontour.py:45, in TriContourSet._process_args(self, *args, **kwargs)
#      44 from matplotlib import _tri
# ---> 45 tri, z = self._contour_args(args, kwargs)
#      46 C = _tri.TriContourGenerator(tri.get_cpp_triangulation(), z)
#
# File ~/miniconda3/envs/dlroms-env/lib/python3.11/site-packages/matplotlib/tri/_tricontour.py:69, in TriContourSet._contour_args(self, args, kwargs)
#      68 if not np.isfinite(z_check).all():
# ---> 69     raise ValueError('z array must not contain non-finite values '
#      70                      'within the triangulation')
#      72 z = np.ma.masked_invalid(z, copy=False)
#
# ValueError: z array must not contain non-finite values within the triangulation
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 5
#       2 test_sample = K_geo.sample(0)
#       4 plt.figure(figsize=(3, 3))
# ----> 5 fe.plot(test_sample, V, cmap='jet')
#
# File ~/miniconda3/envs/dlroms-env/lib/python3.11/site-packages/dlroms/fespaces.py:344, in plot(obj, space, vmin, vmax, colorbar, axis, shrink, levels, cmap)
#     342             plt.colorbar(c, shrink = shrink)
#     343 except:
# --> 344     raise RuntimeError("First argument should be either a dolfin.cpp.mesh.Mesh or a structure containing the dof values of some function (in which case 'space' must be != None).")
#     345 plt.axis(axis)
#
# RuntimeError: First argument should be either a dolfin.cpp.mesh.Mesh or a structure containing the dof values of some function (in which case 'space' must be != None).

# %% [markdown]
# ### Darcy flow

# %% [markdown]
# The Darcy flow equation is solved using **mixed finite elements** with third-order Raviart–Thomas elements for the velocity, and fourth-order discontinuous elements for the pressure.

# %%
# Snapshot generation

def Darcy(K, V, mesh):
    """
    Solve the Darcy problem for a given instance of the input random field.
    Args:
        K, input random field
        V, FE space for the input random field
        mesh, input mesh
    """
    r = 10 # source rate
    w = 0.125 # source size

    # Function spaces
    # RT = FunctionSpace(mesh, "RT", 3)
    # DG = FunctionSpace(mesh, "DG", 4)
    # W  = MixedFunctionSpace([RT, DG]) # DEPRECATED
    RT_elem = FiniteElement("RT", mesh.ufl_cell(), 3)
    DG_elem = FiniteElement("DG", mesh.ufl_cell(), 3)
    W_elem = MixedElement([RT_elem, DG_elem])
    W = FunctionSpace(mesh, W_elem) # mixed function space

    # Trial and test functions
    (u, p) = TrialFunctions(W)
    (v, q) = TestFunctions(W)

    # Injection term
    class Injection(UserExpression):
        def __init__(self, w, r, **kwargs):
            self.w = w
            self.r = r
            super().__init__(**kwargs)

        def eval(self, values, x):
            if abs(x[0] - 0.5 * self.w) <= 0.5 * w and abs(x[1] - 0.5 * self.w) <= 0.5 * w:
                values[0] = self.r
            elif abs(x[0] + 0.5 * self.w - 1) <= 0.5 * w and abs(x[1] + 0.5 * self.w - 1) <= 0.5 * w:
                values[0] = - self.r
            else:
                values[0] = 0

        def value_shape(self):
            return ()
    
    f = Injection(w, r, degree=0) # degree?

    # Gaussian field
    class Field(UserExpression):
        def __init__(self, field, **kwargs):
            self.field = field
            super().__init__(**kwargs)

        def eval(self, values, x):
            print(x)
            values[0] = 0

        def value_shape(self):
            return ()

    print(mesh.coordinates())
    # Gaussian random field as function
    k = Field(K.sample(0), degree=1)

    # Variational problem
    a = (dot(u, v) - k * dot(p, div(v)) - dot(u, grad(q))) * dx
    L = f * q * dx + p * dx - k * p * v * ds # Ok to impose int(p) = 0 like this?

    w = Function(W)
    solve(a == L, w)
    (u, p) = w.split()

    plot(p, interactive=True)

    return u, p

# %%
u, p = Darcy(K, V, mesh)
# Out:
# [[0.         0.        ]
#  [1.         0.        ]
#  [1.         1.        ]
#  ...
#  [0.73688455 0.5016909 ]
#  [0.49829314 0.2631708 ]
#  [0.04068727 0.94554525]]
# Can only integrate scalar expressions. The integrand is a tensor expression with value shape (2,) and free indices with labels ().
# ---------------------------------------------------------------------------
# UFLException                              Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 u, p = Darcy(K, V, mesh)
#
# Cell In[37], line 66, in Darcy(K, V, mesh)
#      64 # Variational problem
#      65 a = (dot(u, v) - k * dot(p, div(v)) - dot(u, grad(q))) * dx
# ---> 66 L = f * q * dx + p * dx - k * p * v * ds # Ok to impose int(p) = 0 like this?
#      68 w = Function(W)
#      69 solve(a == L, w)
#
# File ~/miniconda3/envs/dlroms-env/lib/python3.11/site-packages/ufl/measure.py:418, in Measure.__rmul__(self, integrand)
#     416 # Allow only scalar integrands
#     417 if not is_true_ufl_scalar(integrand):
# --> 418     error("Can only integrate scalar expressions. The integrand is a "
#     419           "tensor expression with value shape %s and free indices with labels %s." %
#     420           (integrand.ufl_shape, integrand.ufl_free_indices))
#     422 # If we have a tuple of domain ids, delegate composition to
#     423 # Integral.__add__:
#     424 subdomain_id = self.subdomain_id()
#
# File ~/miniconda3/envs/dlroms-env/lib/python3.11/site-packages/ufl/log.py:172, in Logger.error(self, *message)
#     170 "Write error message and raise an exception."
#     171 self._log.error(*message)
# --> 172 raise self._exception_type(self._format_raw(*message))
#
# UFLException: Can only integrate scalar expressions. The integrand is a tensor expression with value shape (2,) and free indices with labels ().
